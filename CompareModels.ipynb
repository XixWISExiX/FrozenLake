# %% [markdown]
# # Look of FrozenLake

# %%
import gymnasium as gym
from gymnasium.envs.toy_text.frozen_lake import generate_random_map
env = gym.make("FrozenLake-v1", desc=generate_random_map(size=4), map_name="4x4", is_slippery=True, render_mode="human")
observation, info = env.reset(seed=42)
for _ in range(100):
   action = env.action_space.sample()  # this is where you would insert your policy
   # observation, reward, terminated, truncated, info = env.step(action)
   state = env.step(action)
   observation, reward, terminated, truncated, info = state
   print(state)

   if terminated or truncated:
      observation, info = env.reset()

env.close()

# %% [markdown]
# # Compare All Models

# %%
from gymnasium.envs.toy_text.frozen_lake import generate_random_map
import LearningMethods.QLearning as ql
import LearningMethods.SARSA as sar
import LearningMethods.DynamicProgramming as dp
import LearningMethods.EligibilityTraces as ele
import FrozenLakeFunctions as flf
import imp
imp.reload(ql)
imp.reload(sar)
imp.reload(dp)
imp.reload(ele)

size = 8
env_seed = generate_random_map(size=8)
DynamicProgramming_model = dp.DynamicProgramming(env_seed)
QLearning_model = ql.QLearning(5000, env_seed)
Sarsa_model = sar.SARSA(5000, env_seed)
ElegibilityTraces_model = ele.EligibilityTraces(5000, env_seed)
# Out:
# /home/joshua/.local/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.P to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.P` for environment variables or `env.get_wrapper_attr('P')` that will search the reminding wrappers.
#   logger.warn(

# %% [markdown]
# ### See All Models

# %%
import FrozenLakeFunctions as flf
import imp
imp.reload(flf)

flf.seeModelState(DynamicProgramming_model, env_seed)
flf.seeModel(QLearning_model, env_seed)
flf.seeModel(Sarsa_model, env_seed)
flf.seeModel(ElegibilityTraces_model, env_seed)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 8
#       6 flf.seeModel(QLearning_model, env_seed)
#       7 flf.seeModel(Sarsa_model, env_seed)
# ----> 8 flf.seeModel(ElegibilityTraces_model, env_seed)
#
# File ~/Desktop/MainFolder/Projects/FrozenLake/FrozenLake/FrozenLakeFunctions.py:13, in seeModel(model, env_seed)
#      11 while(not terminated and not truncated):
#      12     action = np.argmax(model[state,:])
# ---> 13     new_state,reward,terminated,truncated,_ = env.step(action)
#      14     state = new_state
#      15 env.close()
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/wrappers/env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/envs/toy_text/frozen_lake.py:308, in FrozenLakeEnv.step(self, a)
#     305 self.lastaction = a
#     307 if self.render_mode == "human":
# --> 308     self.render()
#     309 return (int(s), r, t, False, {"prob": p})
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/envs/toy_text/frozen_lake.py:338, in FrozenLakeEnv.render(self)
#     336     return self._render_text()
#     337 else:  # self.render_mode in {"human", "rgb_array"}:
# --> 338     return self._render_gui(self.render_mode)
#
# File ~/.local/lib/python3.10/site-packages/gymnasium/envs/toy_text/frozen_lake.py:432, in FrozenLakeEnv._render_gui(self, mode)
#     430     pygame.event.pump()
#     431     pygame.display.update()
# --> 432     self.clock.tick(self.metadata["render_fps"])
#     433 elif mode == "rgb_array":
#     434     return np.transpose(
#     435         np.array(pygame.surfarray.pixels3d(self.window_surface)), axes=(1, 0, 2)
#     436     )
#
# KeyboardInterrupt:

# %%
import FrozenLakeFunctions as flf
import imp
imp.reload(flf)

flf.visualize_policy(DynamicProgramming_model, size)
flf.testModel(QLearning_model, "QLearning", env_seed, 100)
flf.testModel(Sarsa_model, "SARSA", env_seed, 100, line_style="--")
flf.testModel(ElegibilityTraces_model, "ElegibilityTraces", env_seed, 100, line_style=(0,(3,10)))
flf.seeEnv(env_seed)
# TODO Make GIF AND README
# Out:
# SFHFFFFF
# FFFFFFHF
# FFFFFFFF
# FFFFHFHF
# FFHHFFFF
# HFHFFFFF
# FFHFFHFF
# FFFFFFHG

# %%
# MonteCarlo_model1 = monte.MonteCarlo(50000, env_seed, size)
# MonteCarlo_model2 = monte.MonteCarlo(100000, env_seed, size)
# MonteCarlo_model3 = monte.MonteCarlo(500000, env_seed, size)
# MonteCarlo_model4 = monte.MonteCarlo(1000000, env_seed, size)
